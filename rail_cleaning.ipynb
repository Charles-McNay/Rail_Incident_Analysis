# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('rr_data.csv')
df
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_12240\2796652341.py:1: DtypeWarning: Columns (11,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('rr_data.csv')
#                                   Reporting Railroad Name  \
# 0       Northern Indiana Commuter Transportation District
# 1       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...
# 2                                                 Conrail
# 3                       Illinois Central Railroad Company
# 4                       Illinois Central Railroad Company
# ...                                                   ...
# 215844                           Alton & Southern Railway
# 215845                     Union Pacific Railroad Company
# 215846                     Union Pacific Railroad Company
# 215847                     Union Pacific Railroad Company
# 215848                  Illinois Central Railroad Company
#
#                                 Maintenance Railroad Name        Date  \
# 0       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...  06/06/2017
# 1       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...  06/06/2017
# 2                                                 Conrail  04/06/1981
# 3                                        Cargill Elevator  01/11/2007
# 4                       Illinois Central Railroad Company  10/07/2017
# ...                                                   ...         ...
# 215844                           Alton & Southern Railway  06/21/2017
# 215845                     Union Pacific Railroad Company  12/13/2016
# 215846                     Union Pacific Railroad Company  12/13/2016
# 215847                     Union Pacific Railroad Company  02/01/2017
# 215848                                   STEPHAN CHEMICAL  06/02/2017
#
#             Accident Type  Hazmat Released Cars  Persons Evacuated State Name  \
# 0              Derailment                   0.0              149.0   ILLINOIS
# 1              Derailment                   0.0                0.0   ILLINOIS
# 2          Side collision                   0.0                0.0   NEW YORK
# 3              Derailment                   0.0                0.0  LOUISIANA
# 4       Hwy-rail crossing                   0.0                0.0   ILLINOIS
# ...                   ...                   ...                ...        ...
# 215844   Raking collision                   0.0                0.0   ILLINOIS
# 215845         Derailment                   0.0                0.0   ILLINOIS
# 215846         Derailment                   0.0                0.0   ILLINOIS
# 215847         Derailment                   0.0                0.0   ILLINOIS
# 215848         Derailment                   0.0                0.0   ILLINOIS
#
#        Weather Condition  Train Speed  Gross Tonnage  ...  \
# 0                  Clear         10.0            0.0  ...
# 1                  Clear          0.0            0.0  ...
# 2                   Snow          0.0            0.0  ...
# 3                 Cloudy          4.0        14100.0  ...
# 4                  Clear          0.0         3482.0  ...
# ...                  ...          ...            ...  ...
# 215844             Clear          3.0            0.0  ...
# 215845            Cloudy          9.0            0.0  ...
# 215846            Cloudy          5.0          450.0  ...
# 215847            Cloudy         30.0          563.0  ...
# 215848             Clear          8.0         1104.0  ...
#
#        Remote Control Locomotive Code Positive Alcohol Tests  \
# 0                                 0.0                    0.0
# 1                                 NaN                    NaN
# 2                                 NaN                    0.0
# 3                                 0.0                    NaN
# 4                                 0.0                    NaN
# ...                               ...                    ...
# 215844                            1.0                    NaN
# 215845                            0.0                    NaN
# 215846                            0.0                    NaN
# 215847                            0.0                    0.0
# 215848                            0.0                    0.0
#
#         Positive Drug Tests  Passengers Transported Equipment Damage Cost  \
# 0                       0.0                     Yes               98627.0
# 1                       NaN                     NaN                   0.0
# 2                       0.0                      No                4000.0
# 3                       NaN                      No                5220.0
# 4                       NaN                      No               13000.0
# ...                     ...                     ...                   ...
# 215844                  NaN                      No               13130.0
# 215845                  NaN                      No               36889.0
# 215846                  NaN                      No               24378.0
# 215847                  0.0                      No               59262.0
# 215848                  0.0                      No               52500.0
#
#                                    Primary Accident Cause  \
# 0                             Switch point worn or broken
# 1                             Switch point worn or broken
# 2                                          Cars left foul
# 3                     Switch damaged or out of adjustment
# 4       Highway user deliberately disregarded crossing...
# ...                                                   ...
# 215844            Yard skate slid and failed to stop cars
# 215845  Failure to comply with restricted speed or its...
# 215846  Failure to comply with restricted speed or its...
# 215847  Failure to release hand brakes on car(s) (rail...
# 215848                      Switch previously run through
#
#        Hours Engineers On Duty  Total Persons Killed  Class  \
# 0                          1.0                   0.0     No
# 1                          NaN                   0.0     No
# 2                          NaN                   0.0     1L
# 3                         10.0                   0.0     1L
# 4                          8.0                   0.0     Cl
# ...                        ...                   ...    ...
# 215844                     NaN                   0.0     Cl
# 215845                     3.0                   0.0     CL
# 215846                     NaN                   0.0     CL
# 215847                     5.0                   0.0     CL
# 215848                     3.0                   0.0     Cl
#
#        Equipment Type Code
# 0                        3
# 1                      NaN
# 2                        5
# 3                        1
# 4                        1
# ...                    ...
# 215844                   6
# 215845                   8
# 215846                   6
# 215847                   4
# 215848                   1
#
# [215849 rows x 21 columns]

# %%
df.drop(['Class', 'Hours Engineers On Duty', 'Maintenance Railroad Name', 'Equipment Attended'], axis=1, inplace=True)
df
# Out:
#                                   Reporting Railroad Name        Date  \
# 0       Northern Indiana Commuter Transportation District  06/06/2017
# 1       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...  06/06/2017
# 2                                                 Conrail  04/06/1981
# 3                       Illinois Central Railroad Company  01/11/2007
# 4                       Illinois Central Railroad Company  10/07/2017
# ...                                                   ...         ...
# 215844                           Alton & Southern Railway  06/21/2017
# 215845                     Union Pacific Railroad Company  12/13/2016
# 215846                     Union Pacific Railroad Company  12/13/2016
# 215847                     Union Pacific Railroad Company  02/01/2017
# 215848                  Illinois Central Railroad Company  06/02/2017
#
#             Accident Type  Hazmat Released Cars  Persons Evacuated State Name  \
# 0              Derailment                   0.0              149.0   ILLINOIS
# 1              Derailment                   0.0                0.0   ILLINOIS
# 2          Side collision                   0.0                0.0   NEW YORK
# 3              Derailment                   0.0                0.0  LOUISIANA
# 4       Hwy-rail crossing                   0.0                0.0   ILLINOIS
# ...                   ...                   ...                ...        ...
# 215844   Raking collision                   0.0                0.0   ILLINOIS
# 215845         Derailment                   0.0                0.0   ILLINOIS
# 215846         Derailment                   0.0                0.0   ILLINOIS
# 215847         Derailment                   0.0                0.0   ILLINOIS
# 215848         Derailment                   0.0                0.0   ILLINOIS
#
#        Weather Condition  Train Speed  Gross Tonnage  \
# 0                  Clear         10.0            0.0
# 1                  Clear          0.0            0.0
# 2                   Snow          0.0            0.0
# 3                 Cloudy          4.0        14100.0
# 4                  Clear          0.0         3482.0
# ...                  ...          ...            ...
# 215844             Clear          3.0            0.0
# 215845            Cloudy          9.0            0.0
# 215846            Cloudy          5.0          450.0
# 215847            Cloudy         30.0          563.0
# 215848             Clear          8.0         1104.0
#
#        Remote Control Locomotive Code  Positive Alcohol Tests  \
# 0                                 0.0                     0.0
# 1                                 NaN                     NaN
# 2                                 NaN                     0.0
# 3                                 0.0                     NaN
# 4                                 0.0                     NaN
# ...                               ...                     ...
# 215844                            1.0                     NaN
# 215845                            0.0                     NaN
# 215846                            0.0                     NaN
# 215847                            0.0                     0.0
# 215848                            0.0                     0.0
#
#         Positive Drug Tests Passengers Transported  Equipment Damage Cost  \
# 0                       0.0                    Yes                98627.0
# 1                       NaN                    NaN                    0.0
# 2                       0.0                     No                 4000.0
# 3                       NaN                     No                 5220.0
# 4                       NaN                     No                13000.0
# ...                     ...                    ...                    ...
# 215844                  NaN                     No                13130.0
# 215845                  NaN                     No                36889.0
# 215846                  NaN                     No                24378.0
# 215847                  0.0                     No                59262.0
# 215848                  0.0                     No                52500.0
#
#                                    Primary Accident Cause  \
# 0                             Switch point worn or broken
# 1                             Switch point worn or broken
# 2                                          Cars left foul
# 3                     Switch damaged or out of adjustment
# 4       Highway user deliberately disregarded crossing...
# ...                                                   ...
# 215844            Yard skate slid and failed to stop cars
# 215845  Failure to comply with restricted speed or its...
# 215846  Failure to comply with restricted speed or its...
# 215847  Failure to release hand brakes on car(s) (rail...
# 215848                      Switch previously run through
#
#         Total Persons Killed Equipment Type Code
# 0                        0.0                   3
# 1                        0.0                 NaN
# 2                        0.0                   5
# 3                        0.0                   1
# 4                        0.0                   1
# ...                      ...                 ...
# 215844                   0.0                   6
# 215845                   0.0                   8
# 215846                   0.0                   6
# 215847                   0.0                   4
# 215848                   0.0                   1
#
# [215849 rows x 17 columns]

# %%
df.describe()
# Out:
#        Hazmat Released Cars  Persons Evacuated    Train Speed  Gross Tonnage  \
# count         215848.000000      215848.000000  215846.000000  215848.000000
# mean               0.016558           2.131588      11.616676    3178.910048
# std                0.268810         146.071912      15.154610    4345.934609
# min                0.000000           0.000000       0.000000       0.000000
# 25%                0.000000           0.000000       3.000000       0.000000
# 50%                0.000000           0.000000       5.000000    1490.000000
# 75%                0.000000           0.000000      12.000000    5150.000000
# max               32.000000       50000.000000     150.000000   99000.000000
#
#        Positive Alcohol Tests  Positive Drug Tests  Equipment Damage Cost  \
# count            76380.000000         76750.000000           2.158480e+05
# mean                 0.005027             0.006827           4.148435e+04
# std                  0.080428             0.090488           2.096511e+05
# min                  0.000000             0.000000           0.000000e+00
# 25%                  0.000000             0.000000           2.000000e+03
# 50%                  0.000000             0.000000           7.525000e+03
# 75%                  0.000000             0.000000           2.120725e+04
# max                  2.000000             6.000000           2.714000e+07
#
#        Total Persons Killed
# count         215848.000000
# mean               0.019384
# std                0.262744
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.000000
# max               47.000000

# %%
df.columns
# Out:
# Index(['Reporting Railroad Name', 'Date', 'Accident Type',
#        'Hazmat Released Cars', 'Persons Evacuated', 'State Name',
#        'Weather Condition', 'Train Speed', 'Gross Tonnage',
#        'Remote Control Locomotive Code', 'Positive Alcohol Tests',
#        'Positive Drug Tests', 'Passengers Transported',
#        'Equipment Damage Cost', 'Primary Accident Cause',
#        'Total Persons Killed', 'Equipment Type Code'],
#       dtype='object')

# %%
drop_rows = [2, 3, 'B', 'C', 'EMU', 'DMU']

# %%
df.rename(columns= {'Equipment Type Code': 'Equipment', 
'Weather Condition': 'Weather', 
'Train Speed': 'Speed', 
'Reporting Railroad Name': 'Railroad', 
'State Name': 'State', 
'Equipment Damage Cost': 'Damage',
'Primary Accident Cause': 'Cause',
'Remote Control Locomotive Code': 'RCO',
'Passengers Transported': 'Passengers',
'Accident Type': 'Accident_Type',
'Persons Evacuated': 'Persons_Evacuated',
'Positive Alcohol Tests': 'Alcohol_Test',
'Positive Drug Tests': 'Drug_Test',
'Hazmat Released Cars': 'Hazmat_Spill_Cars',
'Total Persons Killed': 'Lives_Lost',
'Gross Tonnage': 'Tonnage'}, inplace=True)

df
# Out:
#                                                  Railroad        Date  \
# 0       Northern Indiana Commuter Transportation District  06/06/2017
# 1       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...  06/06/2017
# 2                                                 Conrail  04/06/1981
# 3                       Illinois Central Railroad Company  01/11/2007
# 4                       Illinois Central Railroad Company  10/07/2017
# ...                                                   ...         ...
# 215844                           Alton & Southern Railway  06/21/2017
# 215845                     Union Pacific Railroad Company  12/13/2016
# 215846                     Union Pacific Railroad Company  12/13/2016
# 215847                     Union Pacific Railroad Company  02/01/2017
# 215848                  Illinois Central Railroad Company  06/02/2017
#
#             Accident_Type  Hazmat_Spill_Cars  Persons_Evacuated      State  \
# 0              Derailment                0.0              149.0   ILLINOIS
# 1              Derailment                0.0                0.0   ILLINOIS
# 2          Side collision                0.0                0.0   NEW YORK
# 3              Derailment                0.0                0.0  LOUISIANA
# 4       Hwy-rail crossing                0.0                0.0   ILLINOIS
# ...                   ...                ...                ...        ...
# 215844   Raking collision                0.0                0.0   ILLINOIS
# 215845         Derailment                0.0                0.0   ILLINOIS
# 215846         Derailment                0.0                0.0   ILLINOIS
# 215847         Derailment                0.0                0.0   ILLINOIS
# 215848         Derailment                0.0                0.0   ILLINOIS
#
#        Weather  Speed  Tonnage  RCO  Alcohol_Test  Drug_Test Passengers  \
# 0        Clear   10.0      0.0  0.0           0.0        0.0        Yes
# 1        Clear    0.0      0.0  NaN           NaN        NaN        NaN
# 2         Snow    0.0      0.0  NaN           0.0        0.0         No
# 3       Cloudy    4.0  14100.0  0.0           NaN        NaN         No
# 4        Clear    0.0   3482.0  0.0           NaN        NaN         No
# ...        ...    ...      ...  ...           ...        ...        ...
# 215844   Clear    3.0      0.0  1.0           NaN        NaN         No
# 215845  Cloudy    9.0      0.0  0.0           NaN        NaN         No
# 215846  Cloudy    5.0    450.0  0.0           NaN        NaN         No
# 215847  Cloudy   30.0    563.0  0.0           0.0        0.0         No
# 215848   Clear    8.0   1104.0  0.0           0.0        0.0         No
#
#          Damage                                              Cause  \
# 0       98627.0                        Switch point worn or broken
# 1           0.0                        Switch point worn or broken
# 2        4000.0                                     Cars left foul
# 3        5220.0                Switch damaged or out of adjustment
# 4       13000.0  Highway user deliberately disregarded crossing...
# ...         ...                                                ...
# 215844  13130.0            Yard skate slid and failed to stop cars
# 215845  36889.0  Failure to comply with restricted speed or its...
# 215846  24378.0  Failure to comply with restricted speed or its...
# 215847  59262.0  Failure to release hand brakes on car(s) (rail...
# 215848  52500.0                      Switch previously run through
#
#         Lives_Lost Equipment
# 0              0.0         3
# 1              0.0       NaN
# 2              0.0         5
# 3              0.0         1
# 4              0.0         1
# ...            ...       ...
# 215844         0.0         6
# 215845         0.0         8
# 215846         0.0         6
# 215847         0.0         4
# 215848         0.0         1
#
# [215849 rows x 17 columns]

# %%
df.drop(df.loc[df['Equipment']=='2'].index, inplace=True)
df.drop(df.loc[df['Equipment']=='3'].index, inplace=True)
df.drop(df.loc[df['Equipment']=='B'].index, inplace=True)
df.drop(df.loc[df['Equipment']=='C'].index, inplace=True)
df.drop(df.loc[df['Equipment']=='EMU'].index, inplace=True)
df.drop(df.loc[df['Equipment']=='DMU'].index, inplace=True)
df
# Out:
#                                                  Railroad        Date  \
# 1       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...  06/06/2017
# 2                                                 Conrail  04/06/1981
# 3                       Illinois Central Railroad Company  01/11/2007
# 4                       Illinois Central Railroad Company  10/07/2017
# 5                        Norfolk Southern Railway Company  10/15/2017
# ...                                                   ...         ...
# 215844                           Alton & Southern Railway  06/21/2017
# 215845                     Union Pacific Railroad Company  12/13/2016
# 215846                     Union Pacific Railroad Company  12/13/2016
# 215847                     Union Pacific Railroad Company  02/01/2017
# 215848                  Illinois Central Railroad Company  06/02/2017
#
#             Accident_Type  Hazmat_Spill_Cars  Persons_Evacuated      State  \
# 1              Derailment                0.0                0.0   ILLINOIS
# 2          Side collision                0.0                0.0   NEW YORK
# 3              Derailment                0.0                0.0  LOUISIANA
# 4       Hwy-rail crossing                0.0                0.0   ILLINOIS
# 5              Derailment                0.0                0.0   ILLINOIS
# ...                   ...                ...                ...        ...
# 215844   Raking collision                0.0                0.0   ILLINOIS
# 215845         Derailment                0.0                0.0   ILLINOIS
# 215846         Derailment                0.0                0.0   ILLINOIS
# 215847         Derailment                0.0                0.0   ILLINOIS
# 215848         Derailment                0.0                0.0   ILLINOIS
#
#        Weather  Speed  Tonnage  RCO  Alcohol_Test  Drug_Test Passengers  \
# 1        Clear    0.0      0.0  NaN           NaN        NaN        NaN
# 2         Snow    0.0      0.0  NaN           0.0        0.0         No
# 3       Cloudy    4.0  14100.0  0.0           NaN        NaN         No
# 4        Clear    0.0   3482.0  0.0           NaN        NaN         No
# 5         Rain    3.0   6706.0  0.0           0.0        0.0         No
# ...        ...    ...      ...  ...           ...        ...        ...
# 215844   Clear    3.0      0.0  1.0           NaN        NaN         No
# 215845  Cloudy    9.0      0.0  0.0           NaN        NaN         No
# 215846  Cloudy    5.0    450.0  0.0           NaN        NaN         No
# 215847  Cloudy   30.0    563.0  0.0           0.0        0.0         No
# 215848   Clear    8.0   1104.0  0.0           0.0        0.0         No
#
#          Damage                                              Cause  \
# 1           0.0                        Switch point worn or broken
# 2        4000.0                                     Cars left foul
# 3        5220.0                Switch damaged or out of adjustment
# 4       13000.0  Highway user deliberately disregarded crossing...
# 5        7418.0  Shoving movement, absence of man on or at lead...
# ...         ...                                                ...
# 215844  13130.0            Yard skate slid and failed to stop cars
# 215845  36889.0  Failure to comply with restricted speed or its...
# 215846  24378.0  Failure to comply with restricted speed or its...
# 215847  59262.0  Failure to release hand brakes on car(s) (rail...
# 215848  52500.0                      Switch previously run through
#
#         Lives_Lost Equipment
# 1              0.0       NaN
# 2              0.0         5
# 3              0.0         1
# 4              0.0         1
# 5              0.0         1
# ...            ...       ...
# 215844         0.0         6
# 215845         0.0         8
# 215846         0.0         6
# 215847         0.0         4
# 215848         0.0         1
#
# [211276 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 211276 entries, 1 to 215848
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Railroad           211273 non-null  object
#  1   Date               211274 non-null  object
#  2   Accident_Type      211274 non-null  object
#  3   Hazmat_Spill_Cars  211275 non-null  float64
#  4   Persons_Evacuated  211275 non-null  float64
#  5   State              211275 non-null  object
#  6   Weather            210882 non-null  object
#  7   Speed              211273 non-null  float64
#  8   Tonnage            211275 non-null  float64
#  9   RCO                51393 non-null   object
#  10  Alcohol_Test       75718 non-null   float64
#  11  Drug_Test          76081 non-null   float64
#  12  Passengers         200633 non-null  object
#  13  Damage             211275 non-null  float64
#  14  Cause              210178 non-null  object
#  15  Lives_Lost         211275 non-null  float64
#  16  Equipment          200067 non-null  object
# dtypes: float64(8), object(9)
# memory usage: 29.0+ MB

# %%
df = df.dropna(subset=['Equipment', 'Railroad'])
df
# Out:
#                                     Railroad        Date      Accident_Type  \
# 2                                    Conrail  04/06/1981     Side collision
# 3          Illinois Central Railroad Company  01/11/2007         Derailment
# 4          Illinois Central Railroad Company  10/07/2017  Hwy-rail crossing
# 5           Norfolk Southern Railway Company  10/15/2017         Derailment
# 8       Indiana Harbor Belt Railroad Company  03/30/2017         Derailment
# ...                                      ...         ...                ...
# 215844              Alton & Southern Railway  06/21/2017   Raking collision
# 215845        Union Pacific Railroad Company  12/13/2016         Derailment
# 215846        Union Pacific Railroad Company  12/13/2016         Derailment
# 215847        Union Pacific Railroad Company  02/01/2017         Derailment
# 215848     Illinois Central Railroad Company  06/02/2017         Derailment
#
#         Hazmat_Spill_Cars  Persons_Evacuated      State Weather  Speed  \
# 2                     0.0                0.0   NEW YORK    Snow    0.0
# 3                     0.0                0.0  LOUISIANA  Cloudy    4.0
# 4                     0.0                0.0   ILLINOIS   Clear    0.0
# 5                     0.0                0.0   ILLINOIS    Rain    3.0
# 8                     0.0                0.0   ILLINOIS    Rain   10.0
# ...                   ...                ...        ...     ...    ...
# 215844                0.0                0.0   ILLINOIS   Clear    3.0
# 215845                0.0                0.0   ILLINOIS  Cloudy    9.0
# 215846                0.0                0.0   ILLINOIS  Cloudy    5.0
# 215847                0.0                0.0   ILLINOIS  Cloudy   30.0
# 215848                0.0                0.0   ILLINOIS   Clear    8.0
#
#         Tonnage  RCO  Alcohol_Test  Drug_Test Passengers    Damage  \
# 2           0.0  NaN           0.0        0.0         No    4000.0
# 3       14100.0  0.0           NaN        NaN         No    5220.0
# 4        3482.0  0.0           NaN        NaN         No   13000.0
# 5        6706.0  0.0           0.0        0.0         No    7418.0
# 8        2399.0  0.0           NaN        NaN        NaN  390870.0
# ...         ...  ...           ...        ...        ...       ...
# 215844      0.0  1.0           NaN        NaN         No   13130.0
# 215845      0.0  0.0           NaN        NaN         No   36889.0
# 215846    450.0  0.0           NaN        NaN         No   24378.0
# 215847    563.0  0.0           0.0        0.0         No   59262.0
# 215848   1104.0  0.0           0.0        0.0         No   52500.0
#
#                                                     Cause  Lives_Lost  \
# 2                                          Cars left foul         0.0
# 3                     Switch damaged or out of adjustment         0.0
# 4       Highway user deliberately disregarded crossing...         0.0
# 5       Shoving movement, absence of man on or at lead...         0.0
# 8       Broken Rail - Base [Desc.Changed-Refer to Curr...         0.0
# ...                                                   ...         ...
# 215844            Yard skate slid and failed to stop cars         0.0
# 215845  Failure to comply with restricted speed or its...         0.0
# 215846  Failure to comply with restricted speed or its...         0.0
# 215847  Failure to release hand brakes on car(s) (rail...         0.0
# 215848                      Switch previously run through         0.0
#
#        Equipment
# 2              5
# 3              1
# 4              1
# 5              1
# 8              7
# ...          ...
# 215844         6
# 215845         8
# 215846         6
# 215847         4
# 215848         1
#
# [200065 rows x 17 columns]

# %%
df.Weather = df.Weather.fillna('Unknown')
df.Cause = df.Cause.fillna('Unknown')
df.Passengers = df.Passengers.fillna(0)
df.Accident_Type = df.Accident_Type.fillna('Unknown')
df.RCO = df.RCO.fillna(0)
df.Speed = df.Speed.fillna(0)
df.Alcohol_Test = df.Alcohol_Test.fillna(0)
df.Drug_Test = df.Drug_Test.fillna(0)
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_12240\2901633864.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Weather = df.Weather.fillna('Unknown')
# C:\Users\charl\AppData\Local\Temp\ipykernel_12240\2901633864.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Cause = df.Cause.fillna('Unknown')
# C:\Users\charl\AppData\Local\Temp\ipykernel_12240\2901633864.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Passengers = df.Passengers.fillna(0)
# C:\Users\charl\AppData\Local\Temp\ipykernel_12240\2901633864.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Accident_Type = df.Accident_Type.fillna('Unknown')
# C:\Users\charl\AppData\Local\Temp\ipykernel_12240\2901633864.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.RCO = df.RCO.fillna(0)
# C:\Users\charl\AppData\Local\Temp\ipykernel_12240\2901633864.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Speed = df.Speed.fillna(0)
# C:\Users\charl\AppData\Local\Temp\ipykernel_12240\2901633864.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Alcohol_Test = df.Alcohol_Test.fillna(0)
# C:\Users\charl\AppData\Local\Temp\ipykernel_12240\2901633864.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Drug_Test = df.Drug_Test.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200065 entries, 2 to 215848
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Railroad           200065 non-null  object
#  1   Date               200065 non-null  object
#  2   Accident_Type      200065 non-null  object
#  3   Hazmat_Spill_Cars  200065 non-null  float64
#  4   Persons_Evacuated  200065 non-null  float64
#  5   State              200065 non-null  object
#  6   Weather            200065 non-null  object
#  7   Speed              200065 non-null  float64
#  8   Tonnage            200065 non-null  float64
#  9   RCO                200065 non-null  object
#  10  Alcohol_Test       200065 non-null  float64
#  11  Drug_Test          200065 non-null  float64
#  12  Passengers         200065 non-null  object
#  13  Damage             200065 non-null  float64
#  14  Cause              200065 non-null  object
#  15  Lives_Lost         200065 non-null  float64
#  16  Equipment          200065 non-null  object
# dtypes: float64(8), object(9)
# memory usage: 27.5+ MB

# %%
df = df.reset_index(drop=True)
df.index
# Out:
# RangeIndex(start=0, stop=200065, step=1)

# %%
df
# Out:
#                                     Railroad        Date      Accident_Type  \
# 0                                    Conrail  04/06/1981     Side collision
# 1          Illinois Central Railroad Company  01/11/2007         Derailment
# 2          Illinois Central Railroad Company  10/07/2017  Hwy-rail crossing
# 3           Norfolk Southern Railway Company  10/15/2017         Derailment
# 4       Indiana Harbor Belt Railroad Company  03/30/2017         Derailment
# ...                                      ...         ...                ...
# 200060              Alton & Southern Railway  06/21/2017   Raking collision
# 200061        Union Pacific Railroad Company  12/13/2016         Derailment
# 200062        Union Pacific Railroad Company  12/13/2016         Derailment
# 200063        Union Pacific Railroad Company  02/01/2017         Derailment
# 200064     Illinois Central Railroad Company  06/02/2017         Derailment
#
#         Hazmat_Spill_Cars  Persons_Evacuated      State Weather  Speed  \
# 0                     0.0                0.0   NEW YORK    Snow    0.0
# 1                     0.0                0.0  LOUISIANA  Cloudy    4.0
# 2                     0.0                0.0   ILLINOIS   Clear    0.0
# 3                     0.0                0.0   ILLINOIS    Rain    3.0
# 4                     0.0                0.0   ILLINOIS    Rain   10.0
# ...                   ...                ...        ...     ...    ...
# 200060                0.0                0.0   ILLINOIS   Clear    3.0
# 200061                0.0                0.0   ILLINOIS  Cloudy    9.0
# 200062                0.0                0.0   ILLINOIS  Cloudy    5.0
# 200063                0.0                0.0   ILLINOIS  Cloudy   30.0
# 200064                0.0                0.0   ILLINOIS   Clear    8.0
#
#         Tonnage  RCO  Alcohol_Test  Drug_Test Passengers    Damage  \
# 0           0.0    0           0.0        0.0         No    4000.0
# 1       14100.0  0.0           0.0        0.0         No    5220.0
# 2        3482.0  0.0           0.0        0.0         No   13000.0
# 3        6706.0  0.0           0.0        0.0         No    7418.0
# 4        2399.0  0.0           0.0        0.0          0  390870.0
# ...         ...  ...           ...        ...        ...       ...
# 200060      0.0  1.0           0.0        0.0         No   13130.0
# 200061      0.0  0.0           0.0        0.0         No   36889.0
# 200062    450.0  0.0           0.0        0.0         No   24378.0
# 200063    563.0  0.0           0.0        0.0         No   59262.0
# 200064   1104.0  0.0           0.0        0.0         No   52500.0
#
#                                                     Cause  Lives_Lost  \
# 0                                          Cars left foul         0.0
# 1                     Switch damaged or out of adjustment         0.0
# 2       Highway user deliberately disregarded crossing...         0.0
# 3       Shoving movement, absence of man on or at lead...         0.0
# 4       Broken Rail - Base [Desc.Changed-Refer to Curr...         0.0
# ...                                                   ...         ...
# 200060            Yard skate slid and failed to stop cars         0.0
# 200061  Failure to comply with restricted speed or its...         0.0
# 200062  Failure to comply with restricted speed or its...         0.0
# 200063  Failure to release hand brakes on car(s) (rail...         0.0
# 200064                      Switch previously run through         0.0
#
#        Equipment
# 0              5
# 1              1
# 2              1
# 3              1
# 4              7
# ...          ...
# 200060         6
# 200061         8
# 200062         6
# 200063         4
# 200064         1
#
# [200065 rows x 17 columns]

# %%
df = df.astype({'Tonnage': 'Int64', 'Damage': 'Int64', 
'Lives_Lost': 'Int64', 'Drug_Test': 'Int64', 'Speed': 'Int64',
'Alcohol_Test': 'Int64', 'Hazmat_Spill_Cars': 'Int64',
'Persons_Evacuated': 'Int64'})
df['Date'] = df['Date'].astype('datetime64[ns]')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200065 entries, 0 to 200064
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Railroad           200065 non-null  object
#  1   Date               200065 non-null  datetime64[ns]
#  2   Accident_Type      200065 non-null  object
#  3   Hazmat_Spill_Cars  200065 non-null  Int64
#  4   Persons_Evacuated  200065 non-null  Int64
#  5   State              200065 non-null  object
#  6   Weather            200065 non-null  object
#  7   Speed              200065 non-null  Int64
#  8   Tonnage            200065 non-null  Int64
#  9   RCO                200065 non-null  object
#  10  Alcohol_Test       200065 non-null  Int64
#  11  Drug_Test          200065 non-null  Int64
#  12  Passengers         200065 non-null  object
#  13  Damage             200065 non-null  Int64
#  14  Cause              200065 non-null  object
#  15  Lives_Lost         200065 non-null  Int64
#  16  Equipment          200065 non-null  object
# dtypes: Int64(8), datetime64[ns](1), object(8)
# memory usage: 27.5+ MB

# %%
df
# Out:
#                                     Railroad       Date      Accident_Type  \
# 0                                    Conrail 1981-04-06     Side collision
# 1          Illinois Central Railroad Company 2007-01-11         Derailment
# 2          Illinois Central Railroad Company 2017-10-07  Hwy-rail crossing
# 3           Norfolk Southern Railway Company 2017-10-15         Derailment
# 4       Indiana Harbor Belt Railroad Company 2017-03-30         Derailment
# ...                                      ...        ...                ...
# 200060              Alton & Southern Railway 2017-06-21   Raking collision
# 200061        Union Pacific Railroad Company 2016-12-13         Derailment
# 200062        Union Pacific Railroad Company 2016-12-13         Derailment
# 200063        Union Pacific Railroad Company 2017-02-01         Derailment
# 200064     Illinois Central Railroad Company 2017-06-02         Derailment
#
#         Hazmat_Spill_Cars  Persons_Evacuated      State Weather  Speed  \
# 0                       0                  0   NEW YORK    Snow      0
# 1                       0                  0  LOUISIANA  Cloudy      4
# 2                       0                  0   ILLINOIS   Clear      0
# 3                       0                  0   ILLINOIS    Rain      3
# 4                       0                  0   ILLINOIS    Rain     10
# ...                   ...                ...        ...     ...    ...
# 200060                  0                  0   ILLINOIS   Clear      3
# 200061                  0                  0   ILLINOIS  Cloudy      9
# 200062                  0                  0   ILLINOIS  Cloudy      5
# 200063                  0                  0   ILLINOIS  Cloudy     30
# 200064                  0                  0   ILLINOIS   Clear      8
#
#         Tonnage  RCO  Alcohol_Test  Drug_Test Passengers  Damage  \
# 0             0    0             0          0         No    4000
# 1         14100  0.0             0          0         No    5220
# 2          3482  0.0             0          0         No   13000
# 3          6706  0.0             0          0         No    7418
# 4          2399  0.0             0          0          0  390870
# ...         ...  ...           ...        ...        ...     ...
# 200060        0  1.0             0          0         No   13130
# 200061        0  0.0             0          0         No   36889
# 200062      450  0.0             0          0         No   24378
# 200063      563  0.0             0          0         No   59262
# 200064     1104  0.0             0          0         No   52500
#
#                                                     Cause  Lives_Lost  \
# 0                                          Cars left foul           0
# 1                     Switch damaged or out of adjustment           0
# 2       Highway user deliberately disregarded crossing...           0
# 3       Shoving movement, absence of man on or at lead...           0
# 4       Broken Rail - Base [Desc.Changed-Refer to Curr...           0
# ...                                                   ...         ...
# 200060            Yard skate slid and failed to stop cars           0
# 200061  Failure to comply with restricted speed or its...           0
# 200062  Failure to comply with restricted speed or its...           0
# 200063  Failure to release hand brakes on car(s) (rail...           0
# 200064                      Switch previously run through           0
#
#        Equipment
# 0              5
# 1              1
# 2              1
# 3              1
# 4              7
# ...          ...
# 200060         6
# 200061         8
# 200062         6
# 200063         4
# 200064         1
#
# [200065 rows x 17 columns]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('rr_data.csv')
df
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_30544\2796652341.py:1: DtypeWarning: Columns (11,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('rr_data.csv')
#                                   Reporting Railroad Name  \
# 0       Northern Indiana Commuter Transportation District
# 1       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...
# 2                                                 Conrail
# 3                       Illinois Central Railroad Company
# 4                       Illinois Central Railroad Company
# ...                                                   ...
# 215844                           Alton & Southern Railway
# 215845                     Union Pacific Railroad Company
# 215846                     Union Pacific Railroad Company
# 215847                     Union Pacific Railroad Company
# 215848                  Illinois Central Railroad Company
#
# ...

# %%
df.drop(['Class', 'Hours Engineers On Duty'], axis=1, inplace=True)
df
# Out:
#                                   Reporting Railroad Name  \
# 0       Northern Indiana Commuter Transportation District
# 1       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...
# 2                                                 Conrail
# 3                       Illinois Central Railroad Company
# 4                       Illinois Central Railroad Company
# ...                                                   ...
# 215844                           Alton & Southern Railway
# 215845                     Union Pacific Railroad Company
# 215846                     Union Pacific Railroad Company
# 215847                     Union Pacific Railroad Company
# 215848                  Illinois Central Railroad Company
#
#                                 Maintenance Railroad Name        Date  \
# 0       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...  06/06/2017
# 1       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...  06/06/2017
# ...

# %%
df.describe()
# Out:
#        Hazmat Released Cars  Persons Evacuated    Train Speed  Gross Tonnage  \
# count         215848.000000      215848.000000  215846.000000  215848.000000
# mean               0.016558           2.131588      11.616676    3178.910048
# std                0.268810         146.071912      15.154610    4345.934609
# min                0.000000           0.000000       0.000000       0.000000
# 25%                0.000000           0.000000       3.000000       0.000000
# 50%                0.000000           0.000000       5.000000    1490.000000
# 75%                0.000000           0.000000      12.000000    5150.000000
# max               32.000000       50000.000000     150.000000   99000.000000
#
#        Positive Alcohol Tests  Positive Drug Tests  Equipment Damage Cost  \
# count            76380.000000         76750.000000           2.158480e+05
# mean                 0.005027             0.006827           4.148435e+04
# ...

# %%
df.columns
# Out:
# Index(['Reporting Railroad Name', 'Maintenance Railroad Name', 'Date',
#        'Accident Type', 'Hazmat Released Cars', 'Persons Evacuated',
#        'State Name', 'Weather Condition', 'Train Speed', 'Gross Tonnage',
#        'Equipment Attended', 'Remote Control Locomotive Code',
#        'Positive Alcohol Tests', 'Positive Drug Tests',
#        'Passengers Transported', 'Equipment Damage Cost',
#        'Primary Accident Cause', 'Total Persons Killed',
#        'Equipment Type Code'],
#       dtype='object')

# %%
drop_rows = [2, 3, 'B', 'C', 'EMU', 'DMU']

# %%
df.rename(columns= {'Equipment Type Code': 'Equipment'}, inplace=True)
df
# Out:
#                                   Reporting Railroad Name  \
# 0       Northern Indiana Commuter Transportation District
# 1       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...
# 2                                                 Conrail
# 3                       Illinois Central Railroad Company
# 4                       Illinois Central Railroad Company
# ...                                                   ...
# 215844                           Alton & Southern Railway
# 215845                     Union Pacific Railroad Company
# 215846                     Union Pacific Railroad Company
# 215847                     Union Pacific Railroad Company
# 215848                  Illinois Central Railroad Company
#
#                                 Maintenance Railroad Name        Date  \
# 0       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...  06/06/2017
# 1       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...  06/06/2017
# ...

# %%
df.drop(df.loc[df['Equipment']=='2'].index, inplace=True)
df.drop(df.loc[df['Equipment']=='3'].index, inplace=True)
df.drop(df.loc[df['Equipment']=='B'].index, inplace=True)
df.drop(df.loc[df['Equipment']=='C'].index, inplace=True)
df.drop(df.loc[df['Equipment']=='EMU'].index, inplace=True)
df.drop(df.loc[df['Equipment']=='DMU'].index, inplace=True)
df
# Out:
#                                   Reporting Railroad Name  \
# 1       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...
# 2                                                 Conrail
# 3                       Illinois Central Railroad Company
# 4                       Illinois Central Railroad Company
# 5                        Norfolk Southern Railway Company
# ...                                                   ...
# 215844                           Alton & Southern Railway
# 215845                     Union Pacific Railroad Company
# 215846                     Union Pacific Railroad Company
# 215847                     Union Pacific Railroad Company
# 215848                  Illinois Central Railroad Company
#
#                                 Maintenance Railroad Name        Date  \
# 1       NORTHEAST ILLINOIS REGIONAL COMMUTER RAIL CORP...  06/06/2017
# 2                                                 Conrail  04/06/1981
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 211276 entries, 1 to 215848
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Reporting Railroad Name         211273 non-null  object
#  1   Maintenance Railroad Name       211181 non-null  object
#  2   Date                            211274 non-null  object
#  3   Accident Type                   211274 non-null  object
#  4   Hazmat Released Cars            211275 non-null  float64
#  5   Persons Evacuated               211275 non-null  float64
#  6   State Name                      211275 non-null  object
#  7   Weather Condition               210882 non-null  object
#  8   Train Speed                     211273 non-null  float64
#  9   Gross Tonnage                   211275 non-null  float64
#  10  Equipment Attended              184877 non-null  object
# ...

# %%
df = df.dropna(subset=['Equipment', 'Reporting Railroad Name'])
df
# Out:
#                      Reporting Railroad Name  \
# 2                                    Conrail
# 3          Illinois Central Railroad Company
# 4          Illinois Central Railroad Company
# 5           Norfolk Southern Railway Company
# 8       Indiana Harbor Belt Railroad Company
# ...                                      ...
# 215844              Alton & Southern Railway
# 215845        Union Pacific Railroad Company
# 215846        Union Pacific Railroad Company
# 215847        Union Pacific Railroad Company
# 215848     Illinois Central Railroad Company
#
#                    Maintenance Railroad Name        Date      Accident Type  \
# 2                                    Conrail  04/06/1981     Side collision
# 3                           Cargill Elevator  01/11/2007         Derailment
# 4          Illinois Central Railroad Company  10/07/2017  Hwy-rail crossing
# 5           Norfolk Southern Railway Company  10/15/2017         Derailment
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200065 entries, 2 to 215848
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Reporting Railroad Name         200065 non-null  object
#  1   Maintenance Railroad Name       199973 non-null  object
#  2   Date                            200065 non-null  object
#  3   Accident Type                   200064 non-null  object
#  4   Hazmat Released Cars            200065 non-null  float64
#  5   Persons Evacuated               200065 non-null  float64
#  6   State Name                      200065 non-null  object
#  7   Weather Condition               199712 non-null  object
#  8   Train Speed                     200063 non-null  float64
#  9   Gross Tonnage                   200065 non-null  float64
#  10  Equipment Attended              184148 non-null  object
# ...
